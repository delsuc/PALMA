# %% [markdown]
# # Table S3
# This is a iPython Notebook document, associated to the S3 table in the Support Information of the manuscript:
# # PALMA, an improved algorithm for the DOSY signal processing
# Afef cherni, Émilie chouzenoux, Marc-André Delsuc

# %% [markdown]
# # M = 64

# %%
##############################
# Import bib
##############################
import numpy as np
import matplotlib.pylab as plt
import matplotlib.mlab as mlab
# %matplotlib inline
import time
import scipy
import pandas as pd
############################## noise = 10^-2
# Original data 
Lap_axis_Xu2 = open("Lap_axis_Xu2_64_2.txt", "r")
Lap_axis_Xu2 = np.loadtxt(Lap_axis_Xu2)
x_Xu2_64_2 = open("x_Xu2_64_2.txt", "r")
x_Xu2_64_2 = np.loadtxt(x_Xu2_64_2)
# ITAMeD rslt
xrec_Xu2_64_2_ITAMeD = open("xrec_Xu2_64_2_ITAMeD.txt", "r")
xrec_Xu2_64_2_ITAMeD = np.loadtxt(xrec_Xu2_64_2_ITAMeD)
e_Xu2_64_2_ITAMeD = -20*np.log10(np.linalg.norm(xrec_Xu2_64_2_ITAMeD - x_Xu2_64_2) / np.linalg.norm(x_Xu2_64_2))
# ITAMeD with Lp
xrec_Xu2_64_2_ITAMeD_p = open("xrec_Xu2_64_2_ITAMeD_p.txt", "r")
xrec_Xu2_64_2_ITAMeD_p = np.loadtxt(xrec_Xu2_64_2_ITAMeD_p)
e_Xu2_64_2_ITAMeD_p = -20*np.log10(np.linalg.norm(xrec_Xu2_64_2_ITAMeD_p - x_Xu2_64_2) / np.linalg.norm(x_Xu2_64_2))
# TRAIn rslt
xrec_Xu2_64_2_TRAIn = open("xrec_Xu2_64_2_TRAIn.txt", "r")
xrec_Xu2_64_2_TRAIn = np.loadtxt(xrec_Xu2_64_2_TRAIn)
e_Xu2_64_2_TRAIn = -20*np.log10(np.linalg.norm(xrec_Xu2_64_2_TRAIn - x_Xu2_64_2) / np.linalg.norm(x_Xu2_64_2))
# PALMA rslt 0.01
xrec_Xu2_0_01_64_2_PALMA = open("xrec_Xu2_0_01_64_2_PALMA.txt", "r")
xrec_Xu2_0_01_64_2_PALMA = np.loadtxt(xrec_Xu2_0_01_64_2_PALMA)
e_Xu2_0_01_64_2_PALMA = -20*np.log10(np.linalg.norm(xrec_Xu2_0_01_64_2_PALMA - x_Xu2_64_2) / np.linalg.norm(x_Xu2_64_2))
# PALMA rslt 0.05
xrec_Xu2_0_05_64_2_PALMA = open("xrec_Xu2_0_05_64_2_PALMA.txt", "r")
xrec_Xu2_0_05_64_2_PALMA = np.loadtxt(xrec_Xu2_0_05_64_2_PALMA)
e_Xu2_0_05_64_2_PALMA = -20*np.log10(np.linalg.norm(xrec_Xu2_0_05_64_2_PALMA - x_Xu2_64_2) / np.linalg.norm(x_Xu2_64_2))
# Comparaison
plt.figure(figsize=(12, 8))
plt.semilogx(Lap_axis_Xu2, x_Xu2_64_2, "k--", linewidth = 2, label="reference")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_64_2_ITAMeD, "b-", linewidth = 2, label="ITAMeD")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_64_2_ITAMeD_p, "m-", linewidth = 2, label="ITAMeD $\ell_p$")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_64_2_TRAIn, "g-", linewidth = 2, label="Train")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_0_01_64_2_PALMA, "r-", linewidth = 2, label="PALMA with $\lambda=0.01$")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_0_05_64_2_PALMA, "c-", linewidth = 2, label="PALMA with $\lambda=0.05$")
plt.ylim(ymin=0, ymax=2)
plt.xlim([Lap_axis_Xu2.min(), Lap_axis_Xu2.max()])
plt.title('noise = $10^{-2}$', fontsize=14)
#plt.text(1.5, 4.3, "noise = $10^{-2}$")
plt.xlabel('Diffusion coeff in $\mu m^2 \, s^{-1}$', fontsize=14)
plt.ylabel('Signal', fontsize=14)
plt.legend(fontsize=14)
#plt.savefig('SXu2_comp64_2.eps', format='eps', dpi=1000)
############################## noise = 10^-3
# ITAMeD rslt
xrec_Xu2_64_3_ITAMeD = open("xrec_Xu2_64_3_ITAMeD.txt", "r")
xrec_Xu2_64_3_ITAMeD = np.loadtxt(xrec_Xu2_64_3_ITAMeD)
e_Xu2_64_3_ITAMeD = -20*np.log10(np.linalg.norm(xrec_Xu2_64_3_ITAMeD - x_Xu2_64_2) / np.linalg.norm(x_Xu2_64_2))
#p_Xu2_64_3_ITAMeD = scene.PDI(xrec_Xu2_64_3_ITAMeD, N, Dmin , Dmax)
# ITAMeD with Lp
xrec_Xu2_64_3_ITAMeD_p = open("xrec_Xu2_64_3_ITAMeD_p.txt", "r")
xrec_Xu2_64_3_ITAMeD_p = np.loadtxt(xrec_Xu2_64_3_ITAMeD_p)
e_Xu2_64_3_ITAMeD_p = -20*np.log10(np.linalg.norm(xrec_Xu2_64_3_ITAMeD_p - x_Xu2_64_2) / np.linalg.norm(x_Xu2_64_2))
# TRAIn rslt
xrec_Xu2_64_3_TRAIn = open("xrec_Xu2_64_3_TRAIn.txt", "r")
xrec_Xu2_64_3_TRAIn = np.loadtxt(xrec_Xu2_64_3_TRAIn)
e_Xu2_64_3_TRAIn = -20*np.log10(np.linalg.norm(xrec_Xu2_64_3_TRAIn - x_Xu2_64_2) / np.linalg.norm(x_Xu2_64_2))
# PALMA rslt 0.01
xrec_Xu2_0_01_64_3_PALMA = open("xrec_Xu2_0_01_64_3_PALMA.txt", "r")
xrec_Xu2_0_01_64_3_PALMA = np.loadtxt(xrec_Xu2_0_01_64_3_PALMA)
e_Xu2_0_01_64_3_PALMA = -20*np.log10(np.linalg.norm(xrec_Xu2_0_01_64_3_PALMA - x_Xu2_64_2) / np.linalg.norm(x_Xu2_64_2))
# PALMA rslt 0.05
xrec_Xu2_0_05_64_3_PALMA = open("xrec_Xu2_0_05_64_3_PALMA.txt", "r")
xrec_Xu2_0_05_64_3_PALMA = np.loadtxt(xrec_Xu2_0_05_64_3_PALMA)
e_Xu2_0_05_64_3_PALMA = -20*np.log10(np.linalg.norm(xrec_Xu2_0_05_64_3_PALMA - x_Xu2_64_2) / np.linalg.norm(x_Xu2_64_2))
# Comparaison
plt.figure(figsize=(12, 8))
plt.semilogx(Lap_axis_Xu2, x_Xu2_64_2, "k--", linewidth = 2, label="reference")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_64_3_ITAMeD, "b-", linewidth = 2, label="ITAMeD")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_64_3_ITAMeD_p, "m-", linewidth = 2, label="ITAMeD $\ell_p$")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_64_3_TRAIn, "g-", linewidth = 2, label="Train")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_0_01_64_3_PALMA, "c-", linewidth = 2, label="PALMA with $\lambda=0.01$")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_0_05_64_3_PALMA, "c-", linewidth = 2, label="PALMA with $\lambda=0.05$")
plt.ylim(ymin=0, ymax=2)
plt.xlim([Lap_axis_Xu2.min(), Lap_axis_Xu2.max()])
plt.title('noise = $10^{-3}$', fontsize=14)
#plt.text(1.5, 4.3, "noise = $10^{-3}$", fontsize=14)
plt.xlabel('Diffusion coeff in $\mu m^2 \, s^{-1}$', fontsize=14)
plt.ylabel('Signal', fontsize=14)
plt.legend(fontsize=14)
#plt.savefig('SXu2_comp64_3.eps', format='eps', dpi=1000)
############################## noise = 10^-4
# ITAMeD rslt
xrec_Xu2_64_4_ITAMeD = open("xrec_Xu2_64_4_ITAMeD.txt", "r")
xrec_Xu2_64_4_ITAMeD = np.loadtxt(xrec_Xu2_64_4_ITAMeD)
e_Xu2_64_4_ITAMeD = -20*np.log10(np.linalg.norm(xrec_Xu2_64_4_ITAMeD - x_Xu2_64_2) / np.linalg.norm(x_Xu2_64_2))
#p_Xu2_64_4_ITAMeD = scene.PDI(xrec_Xu2_64_4_ITAMeD, N, Dmin , Dmax)
# ITAMeD with Lp
xrec_Xu2_64_4_ITAMeD_p = open("xrec_Xu2_64_4_ITAMeD_p.txt", "r")
xrec_Xu2_64_4_ITAMeD_p = np.loadtxt(xrec_Xu2_64_4_ITAMeD_p)
e_Xu2_64_4_ITAMeD_p = -20*np.log10(np.linalg.norm(xrec_Xu2_64_4_ITAMeD_p - x_Xu2_64_2) / np.linalg.norm(x_Xu2_64_2))
# TRAIn rslt
xrec_Xu2_64_4_TRAIn = open("xrec_Xu2_64_4_TRAIn.txt", "r")
xrec_Xu2_64_4_TRAIn = np.loadtxt(xrec_Xu2_64_4_TRAIn)
e_Xu2_64_4_TRAIn = -20*np.log10(np.linalg.norm(xrec_Xu2_64_4_TRAIn - x_Xu2_64_2) / np.linalg.norm(x_Xu2_64_2))
# PALMA rslt 0.01
xrec_Xu2_0_01_64_4_PALMA = open("xrec_Xu2_0_01_64_4_PALMA.txt", "r")
xrec_Xu2_0_01_64_4_PALMA = np.loadtxt(xrec_Xu2_0_01_64_4_PALMA)
e_Xu2_0_01_64_4_PALMA = -20*np.log10(np.linalg.norm(xrec_Xu2_0_01_64_4_PALMA - x_Xu2_64_2) / np.linalg.norm(x_Xu2_64_2))
# PALMA rslt 0.05
xrec_Xu2_0_05_64_4_PALMA = open("xrec_Xu2_0_05_64_4_PALMA.txt", "r")
xrec_Xu2_0_05_64_4_PALMA = np.loadtxt(xrec_Xu2_0_05_64_4_PALMA)
e_Xu2_0_05_64_4_PALMA = -20*np.log10(np.linalg.norm(xrec_Xu2_0_05_64_4_PALMA - x_Xu2_64_2) / np.linalg.norm(x_Xu2_64_2))
# Comparaison
plt.figure(figsize=(12, 8))
plt.semilogx(Lap_axis_Xu2, x_Xu2_64_2, "k--", linewidth = 2, label="reference")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_64_4_ITAMeD, "b-", linewidth = 2, label="ITAMeD")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_64_4_ITAMeD_p, "m-", linewidth = 2, label="ITAMeD $\ell_p$")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_64_4_TRAIn, "g-", linewidth = 2, label="Train")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_0_01_64_4_PALMA, "r-", linewidth = 2, label="PALMA with $\lambda=0.01$")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_0_05_64_4_PALMA, "c-", linewidth = 2, label="PALMA with $\lambda=0.05$")
plt.ylim(ymin=0, ymax=2)
plt.xlim([Lap_axis_Xu2.min(), Lap_axis_Xu2.max()])
plt.title('noise = $10^{-4}$', fontsize=14)
#plt.text(1.5, 4.3, "noise = $10^{-4}$")
plt.xlabel('Diffusion coeff in $\mu m^2 \, s^{-1}$', fontsize=14)
plt.ylabel('Signal', fontsize=14)
plt.legend(fontsize=14)
#plt.savefig('SXu2_comp64_4.eps', format='eps', dpi=1000)
############################## noise = 10^-5
# ITAMeD rslt
xrec_Xu2_64_5_ITAMeD = open("xrec_Xu2_64_5_ITAMeD.txt", "r")
xrec_Xu2_64_5_ITAMeD = np.loadtxt(xrec_Xu2_64_5_ITAMeD)
e_Xu2_64_5_ITAMeD = -20*np.log10(np.linalg.norm(xrec_Xu2_64_5_ITAMeD - x_Xu2_64_2) / np.linalg.norm(x_Xu2_64_2))
# ITAMeD with Lp
xrec_Xu2_64_5_ITAMeD_p = open("xrec_Xu2_64_5_ITAMeD_p.txt", "r")
xrec_Xu2_64_5_ITAMeD_p = np.loadtxt(xrec_Xu2_64_5_ITAMeD_p)
e_Xu2_64_5_ITAMeD_p = -20*np.log10(np.linalg.norm(xrec_Xu2_64_5_ITAMeD_p - x_Xu2_64_2) / np.linalg.norm(x_Xu2_64_2))
# TRAIn rslt
xrec_Xu2_64_5_TRAIn = open("xrec_Xu2_64_5_TRAIn.txt", "r")
xrec_Xu2_64_5_TRAIn = np.loadtxt(xrec_Xu2_64_5_TRAIn)
e_Xu2_64_5_TRAIn = -20*np.log10(np.linalg.norm(xrec_Xu2_64_5_TRAIn - x_Xu2_64_2) / np.linalg.norm(x_Xu2_64_2))
# PALMA rslt 0.01
xrec_Xu2_0_01_64_5_PALMA = open("xrec_Xu2_0_01_64_5_PALMA.txt", "r")
xrec_Xu2_0_01_64_5_PALMA = np.loadtxt(xrec_Xu2_0_01_64_5_PALMA)
e_Xu2_0_01_64_5_PALMA = -20*np.log10(np.linalg.norm(xrec_Xu2_0_01_64_5_PALMA - x_Xu2_64_2) / np.linalg.norm(x_Xu2_64_2))
# PALMA rslt 0.05
xrec_Xu2_0_05_64_5_PALMA = open("xrec_Xu2_0_05_64_5_PALMA.txt", "r")
xrec_Xu2_0_05_64_5_PALMA = np.loadtxt(xrec_Xu2_0_05_64_5_PALMA)
e_Xu2_0_05_64_5_PALMA = -20*np.log10(np.linalg.norm(xrec_Xu2_0_05_64_5_PALMA - x_Xu2_64_2) / np.linalg.norm(x_Xu2_64_2))
# Comparaison
plt.figure(figsize=(12, 8))
plt.semilogx(Lap_axis_Xu2, x_Xu2_64_2, "k--", linewidth = 2, label="reference")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_64_5_ITAMeD, "b-", linewidth = 2, label="ITAMeD")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_64_5_ITAMeD_p, "m-", linewidth = 2, label="ITAMeD $\ell_p$")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_64_5_TRAIn, "g-", linewidth = 2, label="Train")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_0_01_64_5_PALMA, "r-", linewidth = 2, label="PALMA with $\lambda=0.01$")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_0_05_64_5_PALMA, "c-", linewidth = 2, label="PALMA with $\lambda=0.05$")
plt.ylim(ymin=0, ymax=2)
plt.xlim([Lap_axis_Xu2.min(), Lap_axis_Xu2.max()])
plt.title('noise = $10^{-5}$', fontsize=14)
#plt.text(1.5, 4.3, "noise = $10^{-5}$", fontsize=14)
plt.xlabel('Diffusion coeff in $\mu m^2 \, s^{-1}$', fontsize=14)
plt.ylabel('Signal', fontsize=14)
plt.legend(fontsize=14)
#plt.savefig('SXu2_comp64_5.eps', format='eps', dpi=1000)
plt.show()
# Qlty reconstruction
E_2 = (e_Xu2_64_2_ITAMeD, e_Xu2_64_2_ITAMeD_p, e_Xu2_64_2_TRAIn, e_Xu2_0_01_64_2_PALMA, e_Xu2_0_05_64_2_PALMA)
E_3 = (e_Xu2_64_3_ITAMeD, e_Xu2_64_3_ITAMeD_p, e_Xu2_64_3_TRAIn, e_Xu2_0_01_64_3_PALMA, e_Xu2_0_05_64_3_PALMA)
E_4 = (e_Xu2_64_4_ITAMeD, e_Xu2_64_4_ITAMeD_p, e_Xu2_64_4_TRAIn, e_Xu2_0_01_64_4_PALMA, e_Xu2_0_05_64_4_PALMA)
E_5 = (e_Xu2_64_5_ITAMeD, e_Xu2_64_5_ITAMeD_p, e_Xu2_64_5_TRAIn, e_Xu2_0_01_64_5_PALMA, e_Xu2_0_05_64_5_PALMA)
tab = pd.DataFrame()
tab["Algorithm/Noise level"]= ("ITAMeD", "ITAMed with $\ell_p$", "TRAIn", "PALMA with $\lambda=0.01$", "PALMA with $\lambda=0.05$")
tab["$10^{-2}$"]  = E_2
tab["$10^{-3}$"]  = E_3
tab["$10^{-4}$"]  = E_4
tab["$10^{-5}$"]  = E_5
tab
# Out:
#        Algorithm/Noise level  $10^{-2}$  $10^{-3}$  $10^{-4}$  $10^{-5}$
# 0                     ITAMeD   1.578576  15.132748  14.365754  14.065410
# 1       ITAMed with $\ell_p$   3.379295   6.307362   6.298927   6.293876
# 2                      TRAIn   8.620229  15.399317  23.369055  25.508262
# 3  PALMA with $\lambda=0.01$  10.600590  12.728091  17.277318  23.249200
# 4  PALMA with $\lambda=0.05$   7.627095  10.972543  16.597174  20.753956

# %% [markdown]
# # M = 32

# %%
##############################
# Import bib
##############################
import numpy as np
import matplotlib.pylab as plt
import matplotlib.mlab as mlab
# %matplotlib inline
import time
import scipy
import pandas as pd
############################## noise = 10^-2
# Original data 
Lap_axis_Xu2 = open("Lap_axis_Xu2_32_2.txt", "r")
Lap_axis_Xu2 = np.loadtxt(Lap_axis_Xu2)
x_Xu2_32_2 = open("x_Xu2_32_2.txt", "r")
x_Xu2_32_2 = np.loadtxt(x_Xu2_32_2)
# ITAMeD rslt
xrec_Xu2_32_2_ITAMeD = open("xrec_Xu2_32_2_ITAMeD.txt", "r")
xrec_Xu2_32_2_ITAMeD = np.loadtxt(xrec_Xu2_32_2_ITAMeD)
e_Xu2_32_2_ITAMeD = -20*np.log10(np.linalg.norm(xrec_Xu2_32_2_ITAMeD - x_Xu2_32_2) / np.linalg.norm(x_Xu2_32_2))
# ITAMeD with Lp
xrec_Xu2_32_2_ITAMeD_p = open("xrec_Xu2_32_2_ITAMeD_p.txt", "r")
xrec_Xu2_32_2_ITAMeD_p = np.loadtxt(xrec_Xu2_32_2_ITAMeD_p)
e_Xu2_32_2_ITAMeD_p = -20*np.log10(np.linalg.norm(xrec_Xu2_32_2_ITAMeD_p - x_Xu2_32_2) / np.linalg.norm(x_Xu2_32_2))
# TRAIn rslt
xrec_Xu2_32_2_TRAIn = open("xrec_Xu2_32_2_TRAIn.txt", "r")
xrec_Xu2_32_2_TRAIn = np.loadtxt(xrec_Xu2_32_2_TRAIn)
e_Xu2_32_2_TRAIn = -20*np.log10(np.linalg.norm(xrec_Xu2_32_2_TRAIn - x_Xu2_32_2) / np.linalg.norm(x_Xu2_32_2))
# PALMA rslt 0.01
xrec_Xu2_0_01_32_2_PALMA = open("xrec_Xu2_0_01_32_2_PALMA.txt", "r")
xrec_Xu2_0_01_32_2_PALMA = np.loadtxt(xrec_Xu2_0_01_32_2_PALMA)
e_Xu2_0_01_32_2_PALMA = -20*np.log10(np.linalg.norm(xrec_Xu2_0_01_32_2_PALMA - x_Xu2_32_2) / np.linalg.norm(x_Xu2_32_2))
# PALMA rslt 0.05
xrec_Xu2_0_05_32_2_PALMA = open("xrec_Xu2_0_05_32_2_PALMA.txt", "r")
xrec_Xu2_0_05_32_2_PALMA = np.loadtxt(xrec_Xu2_0_05_32_2_PALMA)
e_Xu2_0_05_32_2_PALMA = -20*np.log10(np.linalg.norm(xrec_Xu2_0_05_32_2_PALMA - x_Xu2_32_2) / np.linalg.norm(x_Xu2_32_2))
# Comparaison
plt.figure(figsize=(12, 8))
plt.semilogx(Lap_axis_Xu2, x_Xu2_32_2, "k--", linewidth = 2, label="reference")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_32_2_ITAMeD, "b-", linewidth = 2, label="ITAMeD")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_32_2_ITAMeD_p, "m-", linewidth = 2, label="ITAMeD $\ell_p$")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_32_2_TRAIn, "g-", linewidth = 2, label="Train")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_0_01_32_2_PALMA, "r-", linewidth = 2, label="PALMA with $\lambda=0.01$")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_0_05_32_2_PALMA, "c-", linewidth = 2, label="PALMA with $\lambda=0.05$")
plt.ylim(ymin=0, ymax=2)
plt.xlim([Lap_axis_Xu2.min(), Lap_axis_Xu2.max()])
plt.title('noise = $10^{-2}$', fontsize=14)
#plt.text(1.5, 4.3, "noise = $10^{-2}$")
plt.xlabel('Diffusion coeff in $\mu m^2 \, s^{-1}$', fontsize=14)
plt.ylabel('Signal', fontsize=14)
plt.legend(fontsize=14)
#plt.savefig('SXu2_comp64_2.eps', format='eps', dpi=1000)
############################## noise = 10^-3
# ITAMeD rslt
xrec_Xu2_32_3_ITAMeD = open("xrec_Xu2_32_3_ITAMeD.txt", "r")
xrec_Xu2_32_3_ITAMeD = np.loadtxt(xrec_Xu2_32_3_ITAMeD)
e_Xu2_32_3_ITAMeD = -20*np.log10(np.linalg.norm(xrec_Xu2_32_3_ITAMeD - x_Xu2_32_2) / np.linalg.norm(x_Xu2_32_2))
#p_Xu2_32_3_ITAMeD = scene.PDI(xrec_Xu2_32_3_ITAMeD, N, Dmin , Dmax)
# ITAMeD with Lp
xrec_Xu2_32_3_ITAMeD_p = open("xrec_Xu2_32_3_ITAMeD_p.txt", "r")
xrec_Xu2_32_3_ITAMeD_p = np.loadtxt(xrec_Xu2_32_3_ITAMeD_p)
e_Xu2_32_3_ITAMeD_p = -20*np.log10(np.linalg.norm(xrec_Xu2_32_3_ITAMeD_p - x_Xu2_32_2) / np.linalg.norm(x_Xu2_32_2))
# TRAIn rslt
xrec_Xu2_32_3_TRAIn = open("xrec_Xu2_32_3_TRAIn.txt", "r")
xrec_Xu2_32_3_TRAIn = np.loadtxt(xrec_Xu2_32_3_TRAIn)
e_Xu2_32_3_TRAIn = -20*np.log10(np.linalg.norm(xrec_Xu2_32_3_TRAIn - x_Xu2_32_2) / np.linalg.norm(x_Xu2_32_2))
# PALMA rslt 0.01
xrec_Xu2_0_01_32_3_PALMA = open("xrec_Xu2_0_01_32_3_PALMA.txt", "r")
xrec_Xu2_0_01_32_3_PALMA = np.loadtxt(xrec_Xu2_0_01_32_3_PALMA)
e_Xu2_0_01_32_3_PALMA = -20*np.log10(np.linalg.norm(xrec_Xu2_0_01_32_3_PALMA - x_Xu2_32_2) / np.linalg.norm(x_Xu2_32_2))
# PALMA rslt 0.05
xrec_Xu2_0_05_32_3_PALMA = open("xrec_Xu2_0_05_32_3_PALMA.txt", "r")
xrec_Xu2_0_05_32_3_PALMA = np.loadtxt(xrec_Xu2_0_05_32_3_PALMA)
e_Xu2_0_05_32_3_PALMA = -20*np.log10(np.linalg.norm(xrec_Xu2_0_05_32_3_PALMA - x_Xu2_32_2) / np.linalg.norm(x_Xu2_32_2))
# Comparaison
plt.figure(figsize=(12, 8))
plt.semilogx(Lap_axis_Xu2, x_Xu2_32_2, "k--", linewidth = 2, label="reference")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_32_3_ITAMeD, "b-", linewidth = 2, label="ITAMeD")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_32_3_ITAMeD_p, "m-", linewidth = 2, label="ITAMeD $\ell_p$")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_32_3_TRAIn, "g-", linewidth = 2, label="Train")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_0_01_32_3_PALMA, "c-", linewidth = 2, label="PALMA with $\lambda=0.01$")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_0_05_32_3_PALMA, "c-", linewidth = 2, label="PALMA with $\lambda=0.05$")
plt.ylim(ymin=0, ymax=2)
plt.xlim([Lap_axis_Xu2.min(), Lap_axis_Xu2.max()])
plt.title('noise = $10^{-3}$', fontsize=14)
#plt.text(1.5, 4.3, "noise = $10^{-3}$", fontsize=14)
plt.xlabel('Diffusion coeff in $\mu m^2 \, s^{-1}$', fontsize=14)
plt.ylabel('Signal', fontsize=14)
plt.legend(fontsize=14)
#plt.savefig('SXu2_comp64_3.eps', format='eps', dpi=1000)
############################## noise = 10^-4
# ITAMeD rslt
xrec_Xu2_32_4_ITAMeD = open("xrec_Xu2_32_4_ITAMeD.txt", "r")
xrec_Xu2_32_4_ITAMeD = np.loadtxt(xrec_Xu2_32_4_ITAMeD)
e_Xu2_32_4_ITAMeD = -20*np.log10(np.linalg.norm(xrec_Xu2_32_4_ITAMeD - x_Xu2_32_2) / np.linalg.norm(x_Xu2_32_2))
#p_Xu2_32_4_ITAMeD = scene.PDI(xrec_Xu2_32_4_ITAMeD, N, Dmin , Dmax)
# ITAMeD with Lp
xrec_Xu2_32_4_ITAMeD_p = open("xrec_Xu2_32_4_ITAMeD_p.txt", "r")
xrec_Xu2_32_4_ITAMeD_p = np.loadtxt(xrec_Xu2_32_4_ITAMeD_p)
e_Xu2_32_4_ITAMeD_p = -20*np.log10(np.linalg.norm(xrec_Xu2_32_4_ITAMeD_p - x_Xu2_32_2) / np.linalg.norm(x_Xu2_32_2))
# TRAIn rslt
xrec_Xu2_32_4_TRAIn = open("xrec_Xu2_32_4_TRAIn.txt", "r")
xrec_Xu2_32_4_TRAIn = np.loadtxt(xrec_Xu2_32_4_TRAIn)
e_Xu2_32_4_TRAIn = -20*np.log10(np.linalg.norm(xrec_Xu2_32_4_TRAIn - x_Xu2_32_2) / np.linalg.norm(x_Xu2_32_2))
# PALMA rslt 0.01
xrec_Xu2_0_01_32_4_PALMA = open("xrec_Xu2_0_01_32_4_PALMA.txt", "r")
xrec_Xu2_0_01_32_4_PALMA = np.loadtxt(xrec_Xu2_0_01_32_4_PALMA)
e_Xu2_0_01_32_4_PALMA = -20*np.log10(np.linalg.norm(xrec_Xu2_0_01_32_4_PALMA - x_Xu2_32_2) / np.linalg.norm(x_Xu2_32_2))
# PALMA rslt 0.05
xrec_Xu2_0_05_32_4_PALMA = open("xrec_Xu2_0_05_32_4_PALMA.txt", "r")
xrec_Xu2_0_05_32_4_PALMA = np.loadtxt(xrec_Xu2_0_05_32_4_PALMA)
e_Xu2_0_05_32_4_PALMA = -20*np.log10(np.linalg.norm(xrec_Xu2_0_05_32_4_PALMA - x_Xu2_32_2) / np.linalg.norm(x_Xu2_32_2))
# Comparaison
plt.figure(figsize=(12, 8))
plt.semilogx(Lap_axis_Xu2, x_Xu2_32_2, "k--", linewidth = 2, label="reference")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_32_4_ITAMeD, "b-", linewidth = 2, label="ITAMeD")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_32_4_ITAMeD_p, "m-", linewidth = 2, label="ITAMeD $\ell_p$")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_32_4_TRAIn, "g-", linewidth = 2, label="Train")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_0_01_32_4_PALMA, "r-", linewidth = 2, label="PALMA with $\lambda=0.01$")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_0_05_32_4_PALMA, "c-", linewidth = 2, label="PALMA with $\lambda=0.05$")
plt.ylim(ymin=0, ymax=2)
plt.xlim([Lap_axis_Xu2.min(), Lap_axis_Xu2.max()])
plt.title('noise = $10^{-4}$', fontsize=14)
#plt.text(1.5, 4.3, "noise = $10^{-4}$")
plt.xlabel('Diffusion coeff in $\mu m^2 \, s^{-1}$', fontsize=14)
plt.ylabel('Signal', fontsize=14)
plt.legend(fontsize=14)
#plt.savefig('SXu2_comp64_4.eps', format='eps', dpi=1000)
############################## noise = 10^-5
# ITAMeD rslt
xrec_Xu2_32_5_ITAMeD = open("xrec_Xu2_32_5_ITAMeD.txt", "r")
xrec_Xu2_32_5_ITAMeD = np.loadtxt(xrec_Xu2_32_5_ITAMeD)
e_Xu2_32_5_ITAMeD = -20*np.log10(np.linalg.norm(xrec_Xu2_32_5_ITAMeD - x_Xu2_32_2) / np.linalg.norm(x_Xu2_32_2))
# ITAMeD with Lp
xrec_Xu2_32_5_ITAMeD_p = open("xrec_Xu2_32_5_ITAMeD_p.txt", "r")
xrec_Xu2_32_5_ITAMeD_p = np.loadtxt(xrec_Xu2_32_5_ITAMeD_p)
e_Xu2_32_5_ITAMeD_p = -20*np.log10(np.linalg.norm(xrec_Xu2_32_5_ITAMeD_p - x_Xu2_32_2) / np.linalg.norm(x_Xu2_32_2))
# TRAIn rslt
xrec_Xu2_32_5_TRAIn = open("xrec_Xu2_32_5_TRAIn.txt", "r")
xrec_Xu2_32_5_TRAIn = np.loadtxt(xrec_Xu2_32_5_TRAIn)
e_Xu2_32_5_TRAIn = -20*np.log10(np.linalg.norm(xrec_Xu2_32_5_TRAIn - x_Xu2_32_2) / np.linalg.norm(x_Xu2_32_2))
# PALMA rslt 0.01
xrec_Xu2_0_01_32_5_PALMA = open("xrec_Xu2_0_01_32_5_PALMA.txt", "r")
xrec_Xu2_0_01_32_5_PALMA = np.loadtxt(xrec_Xu2_0_01_32_5_PALMA)
e_Xu2_0_01_32_5_PALMA = -20*np.log10(np.linalg.norm(xrec_Xu2_0_01_32_5_PALMA - x_Xu2_32_2) / np.linalg.norm(x_Xu2_32_2))
# PALMA rslt 0.05
xrec_Xu2_0_05_32_5_PALMA = open("xrec_Xu2_0_05_32_5_PALMA.txt", "r")
xrec_Xu2_0_05_32_5_PALMA = np.loadtxt(xrec_Xu2_0_05_32_5_PALMA)
e_Xu2_0_05_32_5_PALMA = -20*np.log10(np.linalg.norm(xrec_Xu2_0_05_32_5_PALMA - x_Xu2_32_2) / np.linalg.norm(x_Xu2_32_2))
# Comparaison
plt.figure(figsize=(12, 8))
plt.semilogx(Lap_axis_Xu2, x_Xu2_32_2, "k--", linewidth = 2, label="reference")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_32_5_ITAMeD, "b-", linewidth = 2, label="ITAMeD")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_32_5_ITAMeD_p, "m-", linewidth = 2, label="ITAMeD $\ell_p$")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_32_5_TRAIn, "g-", linewidth = 2, label="Train")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_0_01_32_5_PALMA, "r-", linewidth = 2, label="PALMA with $\lambda=0.01$")
plt.semilogx(Lap_axis_Xu2, xrec_Xu2_0_05_32_5_PALMA, "c-", linewidth = 2, label="PALMA with $\lambda=0.05$")
plt.ylim(ymin=0, ymax=2)
plt.xlim([Lap_axis_Xu2.min(), Lap_axis_Xu2.max()])
plt.title('noise = $10^{-5}$', fontsize=14)
#plt.text(1.5, 4.3, "noise = $10^{-5}$", fontsize=14)
plt.xlabel('Diffusion coeff in $\mu m^2 \, s^{-1}$', fontsize=14)
plt.ylabel('Signal', fontsize=14)
plt.legend(fontsize=14)
#plt.savefig('SXu2_comp64_5.eps', format='eps', dpi=1000)
plt.show()
# Qlty reconstruction
E_2 = (e_Xu2_32_2_ITAMeD, e_Xu2_32_2_ITAMeD_p, e_Xu2_32_2_TRAIn, e_Xu2_0_01_32_2_PALMA, e_Xu2_0_05_32_2_PALMA)
E_3 = (e_Xu2_32_3_ITAMeD, e_Xu2_32_3_ITAMeD_p, e_Xu2_32_3_TRAIn, e_Xu2_0_01_32_3_PALMA, e_Xu2_0_05_32_3_PALMA)
E_4 = (e_Xu2_32_4_ITAMeD, e_Xu2_32_4_ITAMeD_p, e_Xu2_32_4_TRAIn, e_Xu2_0_01_32_4_PALMA, e_Xu2_0_05_32_4_PALMA)
E_5 = (e_Xu2_32_5_ITAMeD, e_Xu2_32_5_ITAMeD_p, e_Xu2_32_5_TRAIn, e_Xu2_0_01_32_5_PALMA, e_Xu2_0_05_32_5_PALMA)
tab = pd.DataFrame()
tab["Algorithm/Noise level"]= ("ITAMeD", "ITAMed with $\ell_p$", "TRAIn", "PALMA with $\lambda=0.01$", "PALMA with $\lambda=0.05$")
tab["$10^{-2}$"]  = E_2
tab["$10^{-3}$"]  = E_3
tab["$10^{-4}$"]  = E_4
tab["$10^{-5}$"]  = E_5
tab
# Out:
#        Algorithm/Noise level  $10^{-2}$  $10^{-3}$  $10^{-4}$  $10^{-5}$
# 0                     ITAMeD  -3.729335   8.897017  12.891311  13.917416
# 1       ITAMed with $\ell_p$   0.579022   6.188808   6.276369   6.274738
# 2                      TRAIn   3.683430   6.608627   9.393658  18.680604
# 3  PALMA with $\lambda=0.01$  11.095864  14.608032  19.482981  23.040848
# 4  PALMA with $\lambda=0.05$   8.697425  13.096390  18.923820  20.562902
